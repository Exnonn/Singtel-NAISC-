# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Exnonn/Singtel-NAISC-/main/train.csv")

# %%
df
# Out:
#              CustomerID UserGender  UserAge YoungAdultFlag RetireeStatus  \
# 0      1610a102a7854c5d       Male       71             No           Yes
# 1      7b4b47a335af4741       Male       77             No           Yes
# 2      81465cd8c020404b       Male       78             No           Yes
# 3      8fb085ca69574c4c       Male       74             No           Yes
# 4      d2ca70e00e1d419f       Male       71             No           Yes
# ...                 ...        ...      ...            ...           ...
# 70425  fb3438b6b337483c       Male       67             No           Yes
# 70426  52f275304e2644d4     Female       38             No            No
# 70427  ec98152b4c064a06       Male       50             No            No
# 70428  2ba7f39190cf464c       Male       37             No            No
# 70429  fba2ad8bc49045b8       Male       43             No            No
#
#       Married Dependents  NumberofDependents        Country       State  ...  \
# ...
